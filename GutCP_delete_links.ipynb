# %% [markdown]
# ## GutCP (Gut Cross-feeding Predictor) with deletion of links - Ecology-guided prediction of cross-feeding interactions in the human gut microbiome
# The predictive power of the trophic model heavily on a manually curated metabolic interaction network [NJS16](https://www.nature.com/articles/ncomms15393). However, the manually curated network derived from the past experiments and literature is incomplete because not all exchange reactions were revealed by experiments. The number of links in this network is only roughly one-sixth of that in a potentially over-complete cross-feeding network obtained from the genomic annotation. Here, we proposed an ecologically guided machine learning algorithm to cleverly discover metabolite exchange reactions that help to improve the predictions of the trophic level. Later, we demonstrated that the prevalent exchange reactions statistically discovered from many independent simulations are supported by the genomic evidence.
#
# GutCP only add links. An interesting direction worth trying is to delete random links and see if the performance can be improved via the deletion of false-positive links. It starts with the deletion of a random percentage of random links and sees how the performance of the trophic model is worsened by it. Then it runs the GutCP with the ability to delete random links.

# %%
import pandas as pd
import numpy as np
import math
import random
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from scipy.stats import sem

#%% Plot Tong's default setting
SMALL_SIZE = 12
MEDIUM_SIZE = 15
BIGGER_SIZE = 15

plt.rc('font', size=SMALL_SIZE, family='sans-serif', serif='Arial')          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('text')

from matplotlib.ticker import MaxNLocator
my_locator = MaxNLocator(6)

color_list = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

def figure_size_setting(WIDTH):
    #WIDTH = 700.0  # the number latex spits out
    FACTOR = 0.8  # the fraction of the width you'd like the figure to occupy
    fig_width_pt  = WIDTH * FACTOR
    inches_per_pt = 1.0 / 72.27
    golden_ratio  = (np.sqrt(5) - 1.0) / 2.0  # because it looks good
    fig_width_in  = fig_width_pt * inches_per_pt  # figure width in inches
    fig_height_in = fig_width_in * golden_ratio   # figure height in inches
    fig_dims    = [fig_width_in, fig_height_in] # fig dims as a list
    return fig_dims

# %%
########### import the pickled file containing all processed data which are useful for simulations (the processing is
########### done in "Trophic_model_for_gut_data_processing.ipynb")
import pickle
pickle_in = open("Chia_network.pickle","rb")
net, i_selfish, i_intake, names = pickle.load(pickle_in)

pickle_in = open("data.pickle","rb")
metagenome_ID, metagenome, metabolome_ID, metabolome = pickle.load(pickle_in)

# %% [markdown]
# ## Trophic model for the gut microbiome
# The human gut microbial community is complex because of 3 reasons: (1) many microbial species ($\approx$ 570); (2) many metabolites involved ($\approx$ 244); and (3) many microbe-metabolite interactions/links (>4400). Of all types of microbe-metabolite interactions/links, the cross-feeding makes the system more complicated to interpret. Previously, a literature-curated interspecies network of the human gut microbiota, called [NJS16](https://www.nature.com/articles/ncomms15393) is reported. This is an extensive data resource composed of ∼570 microbial species and 3 human cell types metabolically interacting through >4,400 small-molecule transport and macromolecule degradation events.
#
# Here, we devoted to building a Consumer-Resource model (CRM) with trophic levels posted in the paper "[an evidence for a multi-level trophic organization of the human gut microbiome](https://www.biorxiv.org/content/10.1101/603365v1.full-text)". The model is devoted to studying the complex microbe-metabolite network in human guts.
#
# In concise, a trophic level is considered as one round of carbon processing and is composed of two processes: resource allocation to microbes and the following resource/byproduct generation by microbes. The simulation is stopped after several trophic levels because the residence time of resources in the human gut is assumed to be finite.

# %% [markdown]
# ## Create maps of microbes and metabolites to their reduced matrix forms

# %%
#i_nonzero_microbes = net['microbes_ID'].unique()
#i_nonzero_microbes = np.sort(i_nonzero_microbes)
i_nonzero_microbes = metagenome_ID.values.copy()
i_nonzero_metabolites = net['metabolites_ID'].unique()
i_nonzero_metabolites = np.sort(i_nonzero_metabolites)


df_metabolites = pd.DataFrame.from_dict({'oldID': i_nonzero_metabolites, 'newID':list(range(len(i_nonzero_metabolites)))})
df_metabolites.set_index('oldID', inplace=True)
df_microbes = pd.DataFrame.from_dict({'oldID': i_nonzero_microbes, 'newID':list(range(len(i_nonzero_microbes)))})
df_microbes.set_index('oldID', inplace=True)


outgoingNodes = df_metabolites.reindex(net['metabolites_ID'].values).values.flatten()
ingoingNodesTemp = df_microbes.reindex(net['microbes_ID'].values).values.flatten()
edge_types = net.iloc[~np.isnan(ingoingNodesTemp),2].values
outgoingNodes = outgoingNodes[~np.isnan(ingoingNodesTemp)]
ingoingNodes = ingoingNodesTemp[~np.isnan(ingoingNodesTemp)].astype(int)

net_reduced = pd.DataFrame.from_dict({'metabolites': outgoingNodes, 'microbes':ingoingNodes, 'edgeType':edge_types})
net = net_reduced.copy()
net_temp = net.copy()
net['edgeType'][net['edgeType']==5] = 2
net_temp['edgeType'][net_temp['edgeType']==5] = 3
net = net.append(net_temp).drop_duplicates()
net_ori = net.copy()

metagenome_ID_reduced = df_microbes.reindex(metagenome_ID).values.flatten()
metagenome_ID = metagenome_ID_reduced[~np.isnan(metagenome_ID_reduced)].astype(int)

metabolome_ID_reduced = df_metabolites.reindex(metabolome_ID).values.flatten()
metabolome_ID = metabolome_ID_reduced[~np.isnan(metabolome_ID_reduced)].astype(int)


i_selfish_reduced = df_microbes.reindex(i_selfish).values.flatten()
i_selfish = i_selfish_reduced[~np.isnan(i_selfish_reduced)].astype(int)

i_intake_reduced = df_metabolites.loc[i_intake].values.flatten()
i_intake = i_intake_reduced[~np.isnan(i_intake_reduced)].astype(int)

# %% [markdown]
# ## Run the simulation with reduced matrix forms for one individual

# %%
################################# Predict metabolome from individual's metagenome.
from numpy import array
from scipy.sparse import csr_matrix
import numpy.matlib
from scipy.optimize import minimize, rosen, rosen_der
from scipy.stats import pearsonr

MAX_ID_microbes = len(i_nonzero_microbes)  # MAX_ID_microbes is the maximum of ID labels for microbes.
MAX_ID_metabolites = len(i_nonzero_metabolites)  # MAX_ID_metabolites is the maximum of ID labels for metabolites.

def Ain_out(b_real, net):
    '''
    Ain_out is a function used to create sparse matrices made of metabolites and microbes 
    where metabolite consumption and production is considered. The matrices created are "m2b" and "b2m":
    (1) m2b is a matrix determines the nutrient splitting among microbes, and
    (2) b2m is a matrix determines the byproducts generation.
    Both matrices have rows representing bacterial species and columns representing metablolites.
    Two matrices are created based on (1) the metabolite consumption and production network which is 
    encode in "net" as a dataframe, and (2) the experimentally measured bacterial abundance "b_real".
    '''
    valid_index = np.where((net['edgeType']==2) | (net['edgeType']==5))[0]
    row = net['metabolites'].iloc[valid_index]
    col = net['microbes'].iloc[valid_index]
    data = np.ones((len(valid_index),))
    m2b = csr_matrix( (data,(row,col)), shape=(MAX_ID_metabolites, MAX_ID_microbes)).toarray()#.todense()

    valid_index = np.where((net['edgeType']==3) | (net['edgeType']==5))[0]
    row = net['metabolites'].iloc[valid_index]
    col = net['microbes'].iloc[valid_index]
    data = np.ones((len(valid_index),))
    b2m = csr_matrix( (data,(row,col)), shape=(MAX_ID_metabolites, MAX_ID_microbes)).toarray()#.todense()

    ########## Normalize the b2m by out_degree
    out_degree = b2m.sum(0).copy()
    out_degree[out_degree==0]=100
    b2m = (b2m / out_degree)

    ########## Normalize the m2b by proportion of microbial abundance in each individual
    b_real_repmat = numpy.matlib.repmat(b_real[np.newaxis,:], MAX_ID_metabolites, 1)
    m2b = m2b * b_real_repmat
    in_degree = m2b.sum(1)
    in_degree[in_degree==0]=100
    m2b = m2b / numpy.matlib.repmat(in_degree[:,np.newaxis], 1, MAX_ID_microbes)
    m2b = np.float32(m2b)
    b2m = np.float32(b2m)
    return [m2b, b2m]

def m2b_multiple_levels(f, m2b, b2m, numLevels_max):
    '''
    m2b_multiple_levels is a function used to generate matrices involving the calculation of metabolite 
    byproducts and microbial biomass after several trophic levels/layers. Those matrices are:
    (1) m2m_layer is a conversion matrix from the nutrient intake to the metabolite byproducts at a trophic
    level or layer.
    (2) m2m_total is a conversion matrix from the nutrient intake to a summation of metabolite byproducts at
    all trophic levels or layers.
    (3) m2b_total is a conversion matrix from the nutrient intake to a summation of all microbial/bacterial 
    biomass gain at all trophic levels or layers.
    Those matrices are computed based on (1) metabolite consumption matrix "m2b", (2) metabolite byproduct
    generation matrix "b2m", (3) byproduct/leakage fraction "f", and (4) number of trophic levels/layers in the 
    simulation "numLevels_max".
    '''
    m2m_layer = np.zeros((MAX_ID_metabolites, MAX_ID_metabolites, numLevels_max));  
    #m2b_total = np.zeros((MAX_ID_metabolites, MAX_ID_microbes));  
    m2b_total = np.zeros((MAX_ID_metabolites, MAX_ID_metabolites));  
    
    f_mul = numpy.matlib.repmat(f, 1, MAX_ID_metabolites)
    #s_step =  np.dot(b2m, m2b.T) # s_step is the conversion matrix of each trophic level/layer
    s_step =  np.dot(b2m, f_mul*m2b.T) # s_step is the conversion matrix of each trophic level/layer
    s_step_ii = np.eye(MAX_ID_metabolites, MAX_ID_metabolites);
    #f_mul = numpy.matlib.repmat(f[np.newaxis,:], MAX_ID, 1)#numpy.matlib.repmat(f, 1, MAX_ID)
    #f_mul = numpy.matlib.repmat(f, 1, MAX_ID_metabolites)
    
    for ii in range(numLevels_max):
        # m2b_total is a series made of s_step of each layer
        #m2b_total = m2b_total + f_mul**(ii) * s_step_ii
        #m2m_layer[:,:,ii] = f_mul**(ii) * s_step_ii
        m2b_total = m2b_total + s_step_ii
        m2m_layer[:,:,ii] = s_step_ii
        s_step_ii = np.dot(s_step_ii, s_step);  
    m2m_total = m2b_total;
    m2b_total = np.dot((1 - f_mul) * m2b.T, m2b_total) # m2b_total has an extra multiplication of m2b and (1-f).
    return [m2b_total, m2m_total, m2m_layer]

def pred_error(x, b_real, m2b_total, i_intake):
    '''
    pred_error is a function used to compute the logarithmic error between experimentally measured
    metagenome and predicted metagenome computed from the model for a certain nutrient intake. It relies on 
    (1) x: the nutrient intake, (2) i_intake: IDs of the nutrient intake, (3) m2b_total: a conversion matrix 
    from thenutrient intake to the total biomass, and (4) b_real: experimentally measured metagenome. The 
    first three is used to compute the metagenome predicted by the model "ba_pred" and compare it with the 
    experimentally measured metagenome "b_real".
    '''
    x_full = np.zeros((MAX_ID_metabolites,));
    x_full[i_intake] = x;
    
    ba_pred = np.dot(m2b_total, x_full)
    pred_error = (np.log10(ba_pred + 1e-6) - np.log10(b_real +1e-6)) / np.log10(b_real +1e-6);
    pred_error = np.sqrt(np.dot(pred_error, pred_error.T)) #np.sqrt(np.sum(pred_error**2))
    return pred_error

def calc_metabolome(x, m2m_layer, numLevels_max, i_intake):
    '''
    calc_metabolome is a function used to calculate the metabolome from the fitted nutrient intake from the
    model. It relies on (1) x: the nutrient intake, (2) i_intake: IDs of the nutrient intake, (3) m2m_layer: 
    a conversion matrix from the nutrient intake to the metabolite byproducts at a trophic level or layer, 
    and (4) numLevels_max: the number of trophic levels/layers in the model. The metabolome in the model is 
    assumed to be composed of two parts: (1) met_levels: all metabolites in the final trophic level/layer 
    (which is considered to be reaching the end of the gut because of the finite gut length and gut motility.),
    and (2) met_leftover_levels: all unusable metabolites from all previous trophic levels/layers. 
    '''
    i_unused = np.where(np.sum(m2b.T,0) == 0)[0]
    met_levels = np.zeros((MAX_ID_metabolites, numLevels_max));  
    met_leftover_levels = np.zeros((MAX_ID_metabolites, numLevels_max));
    
    x_full = np.zeros((MAX_ID_metabolites,));
    x_full[i_intake] = x;
    
    for ii in range(numLevels_max):
        met_levels[:,ii] = np.dot(m2m_layer[:,:,ii], x_full)
        if ii==0:
            met_leftover_levels[i_unused,ii] = x_full[i_unused]
        else:
            met_leftover_levels[i_unused,ii] = met_levels[i_unused,ii-1]
            
    return [met_levels, met_leftover_levels]

f_byproduct = 0.9
f = f_byproduct * np.ones((MAX_ID_microbes,1));
f[i_selfish] = 0.0;  # The byproduct/leakage fraction f for microbes that don't generate byproducts is set as 0.

numLevels_max = 4

######## Select an ID of a individual and pull out its experimentally measured metagenome:
pa = 5; 
b_real = np.zeros((MAX_ID_microbes,))
b_real[metagenome_ID] = metagenome.iloc[:,pa] / np.sum(metagenome.iloc[:,pa])

######## Compute matrices involving the metabolite consumption and generation:
m2b, b2m = Ain_out(b_real, net)
m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)
#m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(i_nonzero_microbes, i_nonzero_metabolites, f, m2b, b2m, numLevels_max)

######## Assign diet
x0 = np.ones((len(i_intake),)) / len(i_intake)

######## The model is converted into an optimization problem where the nutrient intake is constantly changed to
# minimize the logarithmic error between experimentally measured metagenome and predicted metagenome computed 
# from the model for a certain nutrient intake.
fun = lambda x: pred_error(x, b_real, m2b_total, i_intake)
bnds = ((0, 100), ) * len(x0)
res = minimize(fun, x0, method='SLSQP', bounds=bnds, options={'disp': True, 'maxiter': 1000}, tol=1e-3)
#res = minimize(fun, x0, method='Nelder-Mead', bounds=bnds, options={'disp': True})
#res = minimize(fun, x0, method='TNC', bounds=bnds, options={'disp': True, 'maxiter': 1000})
print(res)

######## As long as the optimized nutrient intake is found by using the above optimization solver, the
# optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
# visually and statistically compared to the experimentally measured metagenome and metabolome.
x_full = np.zeros((MAX_ID_metabolites,));
x_full[i_intake] = res.x;
ba_pred = np.dot(m2b_total, x_full)

#### Metagenome comparison
fig, ax = plt.subplots()
ax.loglog(ba_pred+1e-5, b_real+1e-5, 'ko')
ax.plot([1e-5, 1], [1e-5, 1],'k-')
ax.set_aspect('equal')
ax.set_xlabel('predicted')
ax.set_ylabel('experimentally observed')
ax.set_title('Metagenome comparison')

met_levels, met_leftover_levels = calc_metabolome(res.x, m2m_layer, numLevels_max, i_intake)
metabolome_measured = np.zeros((MAX_ID_metabolites,))
#metabolome_measured[metabolome_ID.values] = metabolome.iloc[:,pa]
metabolome_measured[metabolome_ID] = metabolome.iloc[:,pa]
metabolome_pred = met_levels[:, -1] + met_leftover_levels.sum(1) #np.dot(m2m_total, x_full)
#metabolome_pred = np.dot(m2m_total, x_full)
i_common = np.where(metabolome_measured * metabolome_pred > 1e-5)[0]
metabolome_pred_common = metabolome_pred[i_common] / np.sum(metabolome_pred[i_common])
metabolome_measured_common = metabolome_measured[i_common] / np.sum(metabolome_measured[i_common])

#### Metabolome comparison
fig, ax = plt.subplots()
ax.loglog(metabolome_pred_common+1e-5, metabolome_measured_common+1e-5, 'ko')
ax.plot([1e-5, 1], [1e-5, 1],'k-')
ax.set_aspect('equal')
ax.set_xlabel('predicted')
ax.set_ylabel('experimentally observed')
ax.set_title('Metabolome comparison')

print('-------------------------------------------------------------------------------------------------------------')
print('(Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:')
print(pearsonr(ba_pred[b_real>0], b_real[b_real>0]))
print('(Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:')
print(pearsonr(metabolome_pred_common, metabolome_measured_common))
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.15081328590715
#             Iterations: 16
#             Function evaluations: 338
#             Gradient evaluations: 16
#      fun: 3.15081328590715
#      jac: array([ 0.        ,  0.00985727,  0.00507495,  0.00553924,  0.06272528,
#         0.01278239,  0.03304651,  0.007664  , -0.00600949,  0.01459828,
#         0.00206959,  0.0147886 ,  0.1271221 ,  0.08330926, -0.00155351,
#         0.01078975,  0.08886302,  0.02255565, -0.01123682,  0.01378861])
#  message: 'Optimization terminated successfully'
#     nfev: 338
#      nit: 16
#     njev: 16
#   status: 0
#  success: True
#        x: array([5.00000000e-02, 1.10194482e-01, 4.62981925e+00, 3.86162085e-01,
#        0.00000000e+00, 1.04392453e-16, 0.00000000e+00, 7.21664222e-02,
#        3.79355536e-02, 6.36525129e-17, 4.71538944e-01, 1.65359383e-02,
#        0.00000000e+00, 2.10734346e-16, 3.52982051e-01, 2.22131630e-01,
#        0.00000000e+00, 0.00000000e+00, 2.19500120e-01, 0.00000000e+00])
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# (0.8765075557343968, 1.169259578138045e-12)
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# (0.7502095792844012, 0.0002159956854998387)

# %% [markdown]
# ## Run the simulation with reduced matrix forms for all individuals for NSJ16 links

# %%
net = net_reduced.copy()

corr_list = np.zeros((metabolome.shape[1],2))
diet_list = np.zeros((metabolome.shape[1], 20))
for pa in range(metabolome.shape[1]):
    print(pa)
    ######## Select an ID of a individual and pull out its experimentally measured metagenome:
    b_real = np.zeros((MAX_ID_microbes,))
    b_real[metagenome_ID] = metagenome.iloc[:,pa] / np.sum(metagenome.iloc[:,pa])

    ######## Compute matrices involving the metabolite consumption and generation:
    m2b, b2m = Ain_out(b_real, net)
    m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)

    ######## Assign diet
    x0 = np.ones((len(i_intake),)) / len(i_intake)

    ######## The model is converted into an optimization problem where the nutrient intake is constantly changed to
    # minimize the logarithmic error between experimentally measured metagenome and predicted metagenome computed 
    # from the model for a certain nutrient intake.
    fun = lambda x: pred_error(x, b_real, m2b_total, i_intake)
    bnds = ((0, 100), ) * len(x0)
    res = minimize(fun, x0, method='SLSQP', bounds=bnds, options={'maxiter': 1000}, tol=1e-3)

    ######## As long as the optimized nutrient intake is found by using the above optimization solver, the
    # optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
    # visually and statistically compared to the experimentally measured metagenome and metabolome.
    x_full = np.zeros((MAX_ID_metabolites,));
    x_full[i_intake] = res.x;
    ba_pred = np.dot(m2b_total, x_full)

    met_levels, met_leftover_levels = calc_metabolome(res.x, m2m_layer, numLevels_max, i_intake)
    metabolome_measured = np.zeros((MAX_ID_metabolites,))
    metabolome_measured[metabolome_ID] = metabolome.iloc[:,pa]
    metabolome_pred = met_levels[:, -1] + met_leftover_levels.sum(1)
    i_common = np.where(metabolome_measured * metabolome_pred > 1e-5)[0]
    metabolome_pred_common = metabolome_pred[i_common] / np.sum(metabolome_pred[i_common])
    metabolome_measured_common = metabolome_measured[i_common] / np.sum(metabolome_measured[i_common])
    if i_common.shape[0] >= 2:
        corr_list[pa, 0] = pearsonr(ba_pred[b_real>0], b_real[b_real>0])[0]
        corr_list[pa, 1] = pearsonr(np.log10(metabolome_pred_common+1e-5), np.log10(metabolome_measured_common+1e-5))[0]
    else:
        corr_list[pa, 0] = -1
        corr_list[pa, 1] = -1
    diet_list[pa, :] = res.x

    print('-------------------------------------------------------------------------------------------------------------')
    print('(Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:')
    print(corr_list[pa, 0])
    print('(Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:')
    print(corr_list[pa, 1])
# Out:
# 0
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.4264852667826322
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6529538363213335
# 1
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.9011443312797254
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5125407949535865
# 2
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8058052669743445
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7508803126168367
# 3
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8249328049602644
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7689774569325084
# 4
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.854447148040389
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6821088225230025
# 5
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8765075557343968
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.569951792281159
# 6
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8164449222226515
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5656970852166661
# 7
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.7801013436453278
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5218332256188335
# 8
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.6825815283156419
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7817900834768807
# 9
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.9730412745097231
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5418894661381514
# 10
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.6793249794855232
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6677576541856501
# 11
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8246508928704607
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5653770777636514
# 12
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.978326467409985
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5549022140815238
# 13
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.6875887006717701
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.48940313140968145
# 14
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.6573005189824788
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.4223893032881784
# 15
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.9694045603660771
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5654415398240481
# 16
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.6592519660121644
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7310204743635058
# 17
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.953785465689431
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5519902009997193
# 18
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.7565291161563831
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7304309608075412
# 19
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.9031879630590502
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6832822607229561
# 20
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.7630536986250274
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5774059673776893
# 21
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.7700035345916794
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6679272882344236
# 22
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.902676084804102
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7102119626324975
# 23
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8927271129828811
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7756813437783495
# 24
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.96935779901318
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5352094201755129
# 25
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.4050883391885774
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.3812994999489509
# 26
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.9698716333153009
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.701931276913292
# 27
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8330615223184958
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5939302913346534
# 28
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.899763586164664
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5305577891294646
# 29
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.7790605038069409
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7376868336415021
# 30
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.17689971639403446
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5040594387290794
# 31
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.7108908874329506
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5878886369468715
# 32
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8864630454585144
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6961391678417423
# 33
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.986176875879008
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.592952328995068
# 34
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.5908428407623538
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5871530829855477
# 35
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.3354147936534358
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.45756681663310456
# 36
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.9029675099569258
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.7655944139627233
# 37
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.16592525731382513
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.4624534356331108
# 38
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8287701911734202
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.5758689820996707
# 39
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.852832426091764
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6230555463679136
# 40
# -------------------------------------------------------------------------------------------------------------
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:
# 0.8433786381374087
# (Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:
# 0.6681193791876443

# %%
print("The mean Pearson correlation coefficient is", np.mean(corr_list[:,1]))
# Out:
# The mean Pearson correlation coefficient is 0.610812453562786

# %% [markdown]
# ## Run the simulation with reduced matrix forms for all individuals for NSJ16 links with random proportion of links deleted

# %%
pDel_list = np.linspace(0,0.5,6)
corr_array = np.zeros((pDel_list.shape[0], 50))

for pDel in pDel_list:
    print(pDel)
    for which_replicate in range(50):
        net = net_ori.copy()
        i_x = np.random.choice(range(len(net_ori)), int(len(net_ori) * pDel))
        net.drop(net.index[i_x], inplace=True)

        corr_list = np.zeros((metabolome.shape[1],2))
        diet_list = np.zeros((metabolome.shape[1], 20))
        for pa in range(metabolome.shape[1]):
            ######## Select an ID of a individual and pull out its experimentally measured metagenome:
            b_real = np.zeros((MAX_ID_microbes,))
            b_real[metagenome_ID] = metagenome.iloc[:,pa] / np.sum(metagenome.iloc[:,pa])

            ######## Compute matrices involving the metabolite consumption and generation:
            m2b, b2m = Ain_out(b_real, net)
            m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)

            ######## Assign diet
            x0 = np.ones((len(i_intake),)) / len(i_intake)

            ######## The model is converted into an optimization problem where the nutrient intake is constantly changed to
            # minimize the logarithmic error between experimentally measured metagenome and predicted metagenome computed 
            # from the model for a certain nutrient intake.
            fun = lambda x: pred_error(x, b_real, m2b_total, i_intake)
            bnds = ((0, 100), ) * len(x0)
            res = minimize(fun, x0, method='SLSQP', bounds=bnds, options={'maxiter': 1000}, tol=1e-3)

            ######## As long as the optimized nutrient intake is found by using the above optimization solver, the
            # optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
            # visually and statistically compared to the experimentally measured metagenome and metabolome.
            x_full = np.zeros((MAX_ID_metabolites,));
            x_full[i_intake] = res.x;
            ba_pred = np.dot(m2b_total, x_full)

            met_levels, met_leftover_levels = calc_metabolome(res.x, m2m_layer, numLevels_max, i_intake)
            metabolome_measured = np.zeros((MAX_ID_metabolites,))
            metabolome_measured[metabolome_ID] = metabolome.iloc[:,pa]
            metabolome_pred = met_levels[:, -1] + met_leftover_levels.sum(1)
            i_common = np.where(metabolome_measured * metabolome_pred > 1e-5)[0]
            metabolome_pred_common = metabolome_pred[i_common] / np.sum(metabolome_pred[i_common])
            metabolome_measured_common = metabolome_measured[i_common] / np.sum(metabolome_measured[i_common])
            if i_common.shape[0] >= 2:
                corr_list[pa, 0] = pearsonr(ba_pred[b_real>0], b_real[b_real>0])[0]
                corr_list[pa, 1] = pearsonr(np.log10(metabolome_pred_common+1e-5), np.log10(metabolome_measured_common+1e-5))[0]
            else:
                corr_list[pa, 0] = -1
                corr_list[pa, 1] = -1
            diet_list[pa, :] = res.x
            '''
            print('-------------------------------------------------------------------------------------------------------------')
            print('(Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metagonome:')
            print(corr_list[pa, 0])
            print('(Correlation coefficient, P-value) of the correlation between predicted and experimentally measured metabolome:')
            print(corr_list[pa, 1])
            '''
            corr_array[np.where(pDel_list == pDel)[0], which_replicate] = np.mean(corr_list[:,1])
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5

# %%
from scipy.stats import kruskal
from scipy.stats import ttest_ind
def annotate_kruskal_wallis_test(i1, i2, y, axes):
    x1, x2 = i1+1, i2+1
    #plt.plot([x1, x2], [y, y], lw=1.0, c='k')
    h=0.02
    plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.0, c='k')
    pvalue = ttest_ind(corr_array.transpose()[:,i1], corr_array.transpose()[:,i2])[1]
    if pvalue > 0.05:
        axes.text((x1+x2)*.5, y+h*0.8, "ns", ha='center', va='bottom', color='k', fontsize=14)
    elif pvalue > 0.01:
        axes.text((x1+x2)*.5, y+h*0.5, "*", ha='center', va='bottom', color='k', fontsize=14)
    elif pvalue > 0.001:
        axes.text((x1+x2)*.5, y+h*0.5, "**", ha='center', va='bottom', color='k', fontsize=14)
    else:
        axes.text((x1+x2)*.5, y+h*0.5, "***", ha='center', va='bottom', color='k', fontsize=14)

# %%
fig_dims = figure_size_setting(700)
fig, axes = plt.subplots(1, 1, figsize=fig_dims, sharex=True)
axes.boxplot(corr_array.transpose());
axes.set_xticks(np.array(list(range(len(pDel_list))))+1);
axes.set_xticklabels(np.round(pDel_list,2));
axes.set_xlabel('Fraction of deleted links')
#axes.set_ylabel('Correlation coefficients')
axes.set_ylabel('Correlation between predicted and \n experimentally measured metabolome')

'''
annotate_kruskal_wallis_test(0, 1, 0.7, axes)
annotate_kruskal_wallis_test(0, 2, 0.75, axes)
annotate_kruskal_wallis_test(0, 3, 0.8, axes)
annotate_kruskal_wallis_test(0, 4, 0.85, axes)
annotate_kruskal_wallis_test(0, 5, 0.9, axes)
axes.text(1.5, 0.38, "***: P < $10^{-3}$", ha='center', va='bottom', color='k', fontsize=14)
axes.text(1.5, 0.35, "**: P < $10^{-2}$", ha='center', va='bottom', color='k', fontsize=14)
axes.text(1.5, 0.32, "ns: P > 0.05", ha='center', va='bottom', color='k', fontsize=14)
'''

fig.subplots_adjust(left=.13, bottom=.11, right=.97, top=.97, hspace=0.2)
fig.savefig("./performance_degradation_random_links_deleted.pdf", dpi=600)

# %% [markdown]
# ## Show one example of running algorithms with deletion of links

# %%
df_added = pd.read_csv("added_links_prior_distribution_run1.csv", index_col=0)
df_added['metabolites'] = df_metabolites.loc[df_added['metabolite ID']].values
df_added['microbes'] = df_microbes.loc[df_added['microbes ID']].values
df_added_net = df_added[['metabolites','microbes','edgeType']]
df_added_net.head()
# Out:
#    metabolites  microbes  edgeType
# 0          117         2         2
# 1           10        69         3
# 2          219        63         2
# 3          182        71         2
# 4           55         6         3

# %%
df_deleted = pd.read_csv("deleted_links_prior_distribution_run1.csv", index_col=0)
df_deleted['metabolites'] = df_metabolites.loc[df_deleted['metabolite ID']].values
df_deleted['microbes'] = df_microbes.loc[df_deleted['microbes ID']].values
df_deleted_net = df_deleted[['metabolites','microbes','edgeType']]
df_deleted_net.head()
# Out:
#    metabolites  microbes  edgeType
# 0           47         9         2
# 1          159        61         2
# 2          147        47         2
# 3           55        13         2
# 4          153        56         2

# %%
def compute_error(net):
    corr_list = np.zeros((metabolome.shape[1],2))
    diet_list = np.zeros((metabolome.shape[1], 20))
    for pa in range(metabolome.shape[1]):
        ######## Select an ID of a individual and pull out its experimentally measured metagenome:
        b_real = np.zeros((MAX_ID_microbes,))
        b_real[metagenome_ID] = metagenome.iloc[:,pa] / np.sum(metagenome.iloc[:,pa])

        ######## Compute matrices involving the metabolite consumption and generation:
        m2b, b2m = Ain_out(b_real, net)
        m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)

        ######## Assign diet
        x0 = np.ones((len(i_intake),)) / len(i_intake)

        ######## The model is converted into an optimization problem where the nutrient intake is constantly changed to
        # minimize the logarithmic error between experimentally measured metagenome and predicted metagenome computed 
        # from the model for a certain nutrient intake.
        fun = lambda x: pred_error(x, b_real, m2b_total, i_intake)
        bnds = ((0, 100), ) * len(x0)
        res = minimize(fun, x0, method='SLSQP', bounds=bnds, options={'maxiter': 1000}, tol=1e-3)

        ######## As long as the optimized nutrient intake is found by using the above optimization solver, the
        # optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
        # visually and statistically compared to the experimentally measured metagenome and metabolome.
        x_full = np.zeros((MAX_ID_metabolites,));
        x_full[i_intake] = res.x;
        ba_pred = np.dot(m2b_total, x_full)

        met_levels, met_leftover_levels = calc_metabolome(res.x, m2m_layer, numLevels_max, i_intake)
        metabolome_measured = np.zeros((MAX_ID_metabolites,))
        metabolome_measured[metabolome_ID] = metabolome.iloc[:,pa]
        metabolome_pred = met_levels[:, -1] + met_leftover_levels.sum(1)
        i_common = np.where(metabolome_measured * metabolome_pred > 1e-5)[0]
        metabolome_pred_common = metabolome_pred[i_common] / np.sum(metabolome_pred[i_common])
        metabolome_measured_common = metabolome_measured[i_common] / np.sum(metabolome_measured[i_common])
        if i_common.shape[0] >= 2:
            corr_list[pa, 0] = pearsonr(ba_pred[b_real>0], b_real[b_real>0])[0]
            corr_list[pa, 1] = pearsonr(np.log10(metabolome_pred_common+1e-5), np.log10(metabolome_measured_common+1e-5))[0]
        else:
            corr_list[pa, 0] = -1
            corr_list[pa, 1] = -1
        diet_list[pa, :] = res.x
        
    return list(corr_list[:,1])

# %% [markdown]
# ### Only use links from NSJ16

# %%
net = net_ori.copy()
net = net.drop_duplicates(keep=False)
corr_list = compute_error(net)
print("The mean Pearson correlation coefficient is", np.mean(corr_list))
corr_all_cases = []
corr_all_cases = corr_all_cases + [corr_list]
# Out:
# The mean Pearson correlation coefficient is 0.6176332806699286

# %% [markdown]
# ### Use links from NJS16 + addition of links + deletion of links

# %%
net = net_ori.copy()
net = pd.concat([net, df_added_net])
net = pd.concat([net, df_deleted_net])
net = net.drop_duplicates(keep=False)
corr_list = compute_error(net)
print("The mean Pearson correlation coefficient is", np.mean(corr_list))
corr_all_cases = corr_all_cases + [corr_list]
# Out:
# The mean Pearson correlation coefficient is 0.7499376185754689

# %% [markdown]
# ### Use links from NJS16 + addition of links (deleted links ignored)

# %%
net = net_ori.copy()
net = pd.concat([net, df_added_net])
net = net.drop_duplicates(keep=False)
corr_list = compute_error(net)
print("The mean Pearson correlation coefficient is", np.mean(corr_list))
corr_all_cases = corr_all_cases + [corr_list]
# Out:
# The mean Pearson correlation coefficient is 0.7474089316067004

# %% [markdown]
# ### Use links from NJS16 + deletion of links (added links ignored)

# %%
net = net_ori.copy()
net = pd.concat([net, df_deleted_net])
net = net.drop_duplicates(keep=False)
corr_list = compute_error(net)
print("The mean Pearson correlation coefficient is", np.mean(corr_list))
corr_all_cases = corr_all_cases + [corr_list]
# Out:
# The mean Pearson correlation coefficient is 0.6273303975291333

# %% [markdown]
# ### Visulation of effects of addition vs deletion

# %%
from scipy.stats import kruskal
def annotate_kruskal_wallis_test(i1, i2, y, axes):
    x1, x2 = i1+1, i2+1
    #plt.plot([x1, x2], [y, y], lw=1.0, c='k')
    h=0.02
    plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.0, c='k')
    pvalue = kruskal(corr_all_cases[i1], corr_all_cases[i2])[1]
    print(pvalue)
    if pvalue > 0.05:
        axes.text((x1+x2)*.5, y+h*0.8, "ns", ha='center', va='bottom', color='k', fontsize=14)
    elif pvalue > 0.01:
        axes.text((x1+x2)*.5, y+h*0.5, "*", ha='center', va='bottom', color='k', fontsize=14)
    elif pvalue > 0.001:
        axes.text((x1+x2)*.5, y+h*0.5, "**", ha='center', va='bottom', color='k', fontsize=14)
    else:
        axes.text((x1+x2)*.5, y+h*0.5, "***", ha='center', va='bottom', color='k', fontsize=14)

# %%
fig_dims = figure_size_setting(1000)
fig, axes = plt.subplots(1, 1, figsize=fig_dims, sharex=True)
axes.boxplot(corr_all_cases);
#axes.set_xlabel('Number of microbial species')
axes.set_ylabel('Correlation between predicted and \n experimentally measured metabolome')
axes.set_xticks(range(1,5))
axes.set_xticklabels(['NJS16', 'NJS16 + GutCP added links\n - GutCP deleted links', 'NJS16 + GutCP \n added links only', 'NJS16 - GutCP \n deleted links'])

annotate_kruskal_wallis_test(0, 1, 0.9, axes)
annotate_kruskal_wallis_test(0, 2, 0.95, axes)
annotate_kruskal_wallis_test(0, 3, 1.0, axes)
axes.text(2.5, 0.43, "***: P < $10^{-3}$", ha='center', va='bottom', color='k', fontsize=14)
axes.text(2.5, 0.4, "ns: P > 0.05", ha='center', va='bottom', color='k', fontsize=14)

fig.subplots_adjust(left=.13, bottom=.11, right=.97, top=.95, hspace=0.2)
fig.savefig("./performance_addition_versus_deletion.pdf", dpi=600)
# Out:
# 1.4905046813159105e-07
# 2.0135257523371715e-07
# 0.7141236735146556

# %% [markdown]
# ## GutCP with deletion of links: Markov Chain Monte Carlo algorithm of proposing random links (exchange reactions) to add or delete and accepting according to the change in performance

# %% [markdown]
# ## Training-test splitting

# %%
import random
######## Select all microbes in the Thai data:
b_real = np.zeros((MAX_ID_microbes,))
b_real[metagenome_ID] = 0.05

######## Compute matrices involving the metabolite consumption and generation:
m2b, b2m = Ain_out(b_real, net)

m2b_ori = (m2b!=0).astype(int).copy()
b2m_ori = (b2m!=0).astype(int).copy()
x_ori = np.concatenate([m2b_ori.flatten(), b2m_ori.flatten()])
net_ori = net.copy()

def pred_error_addingLinks(i_train, x, m2b_ori, b2m_ori, x_ori):
    '''
    pred_error_addingLinks is a function used to compute the logarithmic error between experimentally measured
    metagenome and predicted metagenome computed from the model for a certain nutrient intake. It relies on 
    (1) x: the nutrient intake, (2) i_intake: IDs of the nutrient intake, (3) m2b_total: a conversion matrix 
    from thenutrient intake to the total biomass, and (4) b_real: experimentally measured metagenome. The 
    first three is used to compute the metagenome predicted by the model "ba_pred" and compare it with the 
    experimentally measured metagenome "b_real".
    '''
    max_links = m2b_ori.shape[0] * m2b_ori.shape[1] # maximal number of links = numberr of specis * number of metabolites
    
    ######## Convert x to net structure (convert the adjacency matrix into the edge list):
    thres = 0.1
    x = x - x_ori
    ### delete links:
    net_ori_deleted = net_ori.copy()
    m2b_deleted = x[:max_links].reshape((m2b_ori.shape[0], m2b_ori.shape[1]))
    a = df_metabolites['newID'].values[np.where(m2b_deleted <= -thres)[0]]
    b = metagenome_ID[np.where(m2b_deleted <= -thres)[1]]
    c = [2] * np.where(m2b_deleted <= -thres)[1].shape[0]
    net_deleted = pd.DataFrame({net_ori.columns[0]:list(a), net_ori.columns[1]:list(b), net_ori.columns[2]:c})
    net_ori_deleted = pd.concat([net_ori_deleted, net_deleted]).drop_duplicates(keep=False)
    ### consumption links:
    m2b_added = x[:max_links].reshape((m2b_ori.shape[0], m2b_ori.shape[1]))
    a = df_metabolites['newID'].values[np.where(m2b_added >= thres)[0]]
    b = metagenome_ID[np.where(m2b_added >= thres)[1]]
    c = [2] * np.where(m2b_added >= thres)[1].shape[0]
    net_added_consumption = pd.DataFrame({net_ori.columns[0]:list(a), net_ori.columns[1]:list(b), net_ori.columns[2]:c})
    ### production links:
    b2m_added = x[max_links:].reshape((m2b_ori.shape[0], m2b_ori.shape[1]))
    a = df_metabolites['newID'].values[np.where(b2m_added >= thres)[0]]
    b = metagenome_ID[np.where(b2m_added >= thres)[1]]
    c = [3] * np.where(b2m_added >= thres)[1].shape[0]
    net_added_production = pd.DataFrame({net_ori.columns[0]:list(a), net_ori.columns[1]:list(b), net_ori.columns[2]:c})
    ### overall edge list of the new network
    net = pd.concat([net_ori_deleted, net_added_consumption, net_added_production])
    
    f_byproduct = 0.9
    f = f_byproduct * np.ones((MAX_ID_microbes,1));
    f[i_selfish] = 0.0;  # The byproduct/leakage fraction f for microbes that don't generate byproducts is set as 0.

    numLevels_max = 4

    corr_list_aveDiet = np.zeros((i_train.shape[0], 2))
    log_list_aveDiet = np.zeros((i_train.shape[0], 2))
    order_dev_list = np.zeros((i_train.shape[0], MAX_ID_metabolites)) ## order difference in metabolome
    order_dev_metagenome_list = np.zeros((i_train.shape[0], MAX_ID_microbes)) ## order difference in metagenome
    numMetabolites_list = np.zeros((i_train.shape[0]))
    for pa in range(i_train.shape[0]):
        ######## Select an ID of a individual and pull out its experimentally measured metagenome:
        b_real = np.zeros((MAX_ID_microbes,))
        b_real[metagenome_ID] = metagenome.iloc[:, i_train[pa]] / np.sum(metagenome.iloc[:, i_train[pa]])

        ######## Compute matrices involving the metabolite consumption and generation:
        m2b, b2m = Ain_out(b_real, net)
        #m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)
        m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)

        ######## As long as the optimized nutrient intake is found by using the above optimization solver, the
        # optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
        # visually and statistically compared to the experimentally measured metagenome and metabolome.
        
        ######## Assign diet
        x0 = np.ones((len(i_intake),)) / len(i_intake)

        ######## The model is converted into an optimization problem where the nutrient intake is constantly changed to
        # minimize the logarithmic error between experimentally measured metagenome and predicted metagenome computed 
        # from the model for a certain nutrient intake.
        fun2 = lambda y: pred_error(y, b_real, m2b_total, i_intake)
        bnds = ((0, 100), ) * len(x0)
        res = minimize(fun2, x0, method='SLSQP', bounds=bnds, options={'disp': False, 'maxiter': 1000}, tol=1e-3, callback=None)

        ######## As long as the optimized nutrient intake is found by using the above optimization solver, the
        # optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
        # visually and statistically compared to the experimentally measured metagenome and metabolome.
        x_full = np.zeros((MAX_ID_metabolites,));
        x_full[i_intake] = res.x;
        ba_pred = np.dot(m2b_total, x_full)

        met_levels, met_leftover_levels = calc_metabolome(res.x, m2m_layer, numLevels_max, i_intake)
        metabolome_measured = np.zeros((MAX_ID_metabolites,))
        metabolome_measured[metabolome_ID] = metabolome.iloc[:, i_train[pa]]
        metabolome_pred = met_levels[:, -1] + met_leftover_levels.sum(1) #np.dot(m2m_total, x_full)
        i_common = np.where(metabolome_measured * metabolome_pred > 1e-5)[0]
        metabolome_pred_common = metabolome_pred[i_common] / np.sum(metabolome_pred[i_common])
        metabolome_measured_common = metabolome_measured[i_common] / np.sum(metabolome_measured[i_common])
        ######## compute the bias of the order of magnitude
        order_dev_metagenome_list[pa, :] = np.log10(b_real + 1e-5) - np.log10(ba_pred + 1e-5)
        order_dev_list[pa, i_common] = np.log10(metabolome_measured_common + 1e-5) - np.log10(metabolome_pred_common + 1e-5)
        numMetabolites_list[pa] = i_common.shape[0]
            
        if i_common.shape[0] >= 2:
            corr_list_aveDiet[pa, 0] = pearsonr(ba_pred[b_real>0], b_real[b_real>0])[0]
            corr_list_aveDiet[pa, 1] = pearsonr(metabolome_pred_common, metabolome_measured_common)[0]
            log_list_aveDiet[pa, 0] = np.mean(np.abs(np.log10(ba_pred[b_real>0]+1e-6) - np.log10(b_real[b_real>0]+1e-6)))
            log_list_aveDiet[pa, 1] = np.mean(np.abs(np.log10(metabolome_pred_common+1e-6) - np.log10(metabolome_measured_common+1e-6)))

        else:
            corr_list_aveDiet[pa, 0] = -1
            corr_list_aveDiet[pa, 1] = -1
            log_list_aveDiet[pa, 0] = 5
            log_list_aveDiet[pa, 1] = 5
            
    x_full = np.zeros((MAX_ID_metabolites,));
    x_full[i_intake] = res.x;
    
    ba_pred = np.dot(m2b_total, x_full)
    
    pred_error1 = np.mean(log_list_aveDiet[:,0])
    pred_error2 = np.mean(log_list_aveDiet[:,1])
    pred_error3 = np.sum(np.abs(x))
    pred_error4 = np.mean(numMetabolites_list)
    hyper_reg = 0.001
    pred_errorTotal = pred_error2 + hyper_reg * pred_error3 - (pred_error4 - 20) * 0.003 # with reward
    
    return [pred_errorTotal, np.abs(np.sum(order_dev_list, 0)), np.sum(order_dev_metagenome_list, 0)]

i_train = np.sort(np.random.choice(range(metabolome.shape[1]), 30, replace=False))
i_test = np.setdiff1d(range(metabolome.shape[1]), i_train)

error_list = []
current_step_list = []
pos_x_list = []
metID_list = []
microbeID_list = []
prior_list = []
fun = lambda x: pred_error_addingLinks(i_train, x, m2b_ori, b2m_ori, x_ori)
max_links = m2b.shape[0]*m2b.shape[1]
x = x_ori.copy()
error_before, bias_metabolome, bias_metagenome = fun(x)
bias_metabolome_ori = bias_metabolome.copy()
prior_prob1 = np.matlib.repmat(np.exp(3 * (bias_metagenome) / metabolome.shape[1])[np.newaxis, :], m2b.shape[0], 1) * np.matlib.repmat(np.exp(3 * bias_metabolome_ori / metabolome.shape[1])[:, np.newaxis], 1, m2b.shape[1])
prior_prob2 = np.matlib.repmat(np.exp(3 * bias_metabolome_ori / metabolome.shape[1])[:, np.newaxis], 1, m2b.shape[1])
prior_prob = np.concatenate([prior_prob1.flatten(), prior_prob2.flatten()]) + 0.1
prior_prob = prior_prob / np.sum(prior_prob)
print('The original error is', error_before)
error_list.append(error_before)

inverseKT = 5000
Twindow = 500
numStepsNotAdded = 0
error_window = []
# MCMC
for i in range(10000):
    if i%50==0:
        print(i)
    if np.random.uniform(0,1,1)[0] < 0.5:
        i_x = np.random.choice(np.where(x==0)[0], 1, p=prior_prob[x==0]/np.sum(prior_prob[x==0]))[0]
    else:
        p_delete = 1.0 / prior_prob[x==1]
        p_delete = p_delete / np.sum(p_delete)
        i_x = np.random.choice(np.where(x==1)[0], 1, p=p_delete)[0]
        #i_x = np.random.choice(np.where(x==1)[0], 1)[0]
    x[i_x] = 1 - x[i_x]
    error_after, bias_metabolome, bias_metagenome = fun(x)
    ## Consumption links:
    prior_prob1 = np.matlib.repmat(np.exp(3 * (bias_metagenome) / metabolome.shape[1])[np.newaxis, :], m2b.shape[0], 1) * np.matlib.repmat(np.exp(3 * bias_metabolome_ori / metabolome.shape[1])[:, np.newaxis], 1, m2b.shape[1])
    ## Production links:
    prior_prob2 = np.matlib.repmat(np.exp(3 * bias_metabolome_ori / metabolome.shape[1])[:, np.newaxis], 1, m2b.shape[1])
    prior_prob = np.concatenate([prior_prob1.flatten(), prior_prob2.flatten()]) + 0.1
    prior_prob = prior_prob / np.sum(prior_prob)
    if np.random.uniform(0,1,1)[0] <= np.min([1, np.exp((inverseKT)*(error_before - error_after))]): 
        error_before = error_after
        if x[i_x] == 1:
            print('Addition accepted, error is', error_before)
        else:
            print('Deletion accepted, error is', error_before)
        error_list.append(error_before)
        current_step_list.append(i)
        pos_x_list.append(i_x)
        prior_list.append(prior_prob[i_x])
        if i_x < max_links:
            row_num = i_x // m2b_ori.shape[1]
            col_num = i_x - row_num * m2b_ori.shape[1]
        elif i_x >= max_links:
            i_x = i_x - m2b_ori.shape[0] * m2b_ori.shape[1]
            row_num = i_x // b2m_ori.shape[1]
            col_num = i_x - row_num * b2m_ori.shape[1]
        metID_list.append(row_num)
        microbeID_list.append(col_num)
        numStepsNotAdded = 0
    else:  ## not accepted   
        x[i_x] = 1 - x[i_x]
        numStepsNotAdded += 1
    error_window.append(error_before)
    if (i > Twindow) and ((error_window[-1] - error_window[-Twindow]) > -(np.sqrt(Twindow) / inverseKT)):
        break
# Out:
# The original error is 0.9182052265414039
# 0
# Addition accepted, error is 0.9175311694870872
# Deletion accepted, error is 0.9165079300725743
# Deletion accepted, error is 0.9043564298444301
# 50
# Addition accepted, error is 0.8892252654664162
# Addition accepted, error is 0.8892075559051827
# Deletion accepted, error is 0.887315819713606
# Addition accepted, error is 0.8842133835779072
# Deletion accepted, error is 0.8687378181662895
# Addition accepted, error is 0.86647611817689
# Addition accepted, error is 0.8668925074871296
# Deletion accepted, error is 0.866249194817257
# Deletion accepted, error is 0.8656684668717608
# 100
# Addition accepted, error is 0.8583394076615627
# Addition accepted, error is 0.8366011108749529
# Addition accepted, error is 0.8342472396994547
# Deletion accepted, error is 0.8352472396994547
# Addition accepted, error is 0.8355107859008006
# Deletion accepted, error is 0.8353051015520842
# 150
# Addition accepted, error is 0.8343157659620405
# Deletion accepted, error is 0.8320037436213769
# Deletion accepted, error is 0.8306554279444452
# Deletion accepted, error is 0.8191938450825904
# Addition accepted, error is 0.8182151205648311
# 200
# Addition accepted, error is 0.8014461799018083
# Deletion accepted, error is 0.8010283084711881
# Deletion accepted, error is 0.799811210852096
# Addition accepted, error is 0.7983726100784387
# 250
# Deletion accepted, error is 0.7981683009031245
# Addition accepted, error is 0.7983537151257128
# Addition accepted, error is 0.797151776036384
# Addition accepted, error is 0.7922727332415588
# Addition accepted, error is 0.7742763197430444
# Addition accepted, error is 0.7663708894128102
# Addition accepted, error is 0.7651033874329671
# Deletion accepted, error is 0.7644855295510179
# 300
# Deletion accepted, error is 0.7644636428325285
# 350
# Addition accepted, error is 0.7654725727130938
# Addition accepted, error is 0.7623052765755418
# Addition accepted, error is 0.7563286656600694
# Addition accepted, error is 0.7561857429380873
# Addition accepted, error is 0.7549104889507577
# Addition accepted, error is 0.7546981616355624
# 400
# Addition accepted, error is 0.7508876825486077
# Addition accepted, error is 0.7505664673201212
# Addition accepted, error is 0.7506150667893515
# Deletion accepted, error is 0.7488943251371865
# Addition accepted, error is 0.7412292025628403
# Addition accepted, error is 0.7378639783884746
# 450
# Deletion accepted, error is 0.7366737084117884
# Addition accepted, error is 0.734728554712356
# 500
# Addition accepted, error is 0.7342907645566642
# Addition accepted, error is 0.7340060680486639
# Addition accepted, error is 0.7305472051715367
# 550
# Addition accepted, error is 0.7285491987993227
# Addition accepted, error is 0.7284929492425364
# 600
# Deletion accepted, error is 0.7280759333155447
# Deletion accepted, error is 0.7263458209084568
# Addition accepted, error is 0.7241534598000604
# Addition accepted, error is 0.7233140940210826
# Deletion accepted, error is 0.7229223657764748
# 650
# Addition accepted, error is 0.716144946557009
# Addition accepted, error is 0.7161729620764254
# Deletion accepted, error is 0.7151820582021762
# Addition accepted, error is 0.7096380828152998
# Addition accepted, error is 0.7090900682632205
# 700
# 750
# Addition accepted, error is 0.706223548979306
# Deletion accepted, error is 0.7065718456272613
# 800
# Addition accepted, error is 0.7059727962287977
# Addition accepted, error is 0.7056721856988489
# 850
# Addition accepted, error is 0.7007725682101988
# 900
# Addition accepted, error is 0.7006846768549504
# Addition accepted, error is 0.6987115394560562
# 950
# Addition accepted, error is 0.6986230856770507
# Addition accepted, error is 0.6973514678550535
# Addition accepted, error is 0.6937956914909997
# 1000
# Deletion accepted, error is 0.6933201778484009
# Addition accepted, error is 0.689935602715093
# Addition accepted, error is 0.6901323710235474
# 1050
# Addition accepted, error is 0.6898983976759543
# Addition accepted, error is 0.6905456873601353
# 1100
# Deletion accepted, error is 0.6901306224355845
# Addition accepted, error is 0.6886854564340035
# 1150
# Addition accepted, error is 0.6876919726491175
# Addition accepted, error is 0.6878889088201107
# 1200
# Deletion accepted, error is 0.6875481275820702
# Deletion accepted, error is 0.6871768124250845
# Deletion accepted, error is 0.6872841354317485
# Deletion accepted, error is 0.6875163259245886
# Addition accepted, error is 0.6755387927844779
# Deletion accepted, error is 0.6752645623478818
# 1250
# Addition accepted, error is 0.6733316823143303
# 1300
# Deletion accepted, error is 0.6743316823143303
# Addition accepted, error is 0.6736872413178056
# 1350
# 1400
# Deletion accepted, error is 0.6732132644402804
# Addition accepted, error is 0.6731800476131894
# 1450
# 1500
# Addition accepted, error is 0.6728326114096341
# 1550
# 1600
# Deletion accepted, error is 0.6726589717327787
# Deletion accepted, error is 0.6720810586749276
# 1650
# Deletion accepted, error is 0.6727595114421269
# Addition accepted, error is 0.6727699413420035
# Addition accepted, error is 0.6728344496219075
# 1700
# Deletion accepted, error is 0.6738344496219075
# Addition accepted, error is 0.6737648322570906

# %% [markdown]
# ## Convert x to network structure and add it to *net*

# %%
######## Convert x to net structure:
a = np.array(metID_list)
b = np.array(microbeID_list)
c = np.ones([len(metID_list)], dtype = int) * 3
c[np.where(np.array(pos_x_list) < max_links)[0]] = 2
net_modified = pd.DataFrame({net_ori.columns[0]:list(a), net_ori.columns[1]:list(b), net_ori.columns[2]:c})
i_added = x[pos_x_list].astype(bool)
i_deleted = ~x[pos_x_list].astype(bool)
net_added = net_modified[i_added]
net_deleted = net_modified[i_deleted]
net_new = pd.concat([net_ori, net_added, net_deleted]).drop_duplicates(keep=False)

print('The original network has',len(net_ori),'links')
print('There are',len(net_added),'links added')
print('There are',len(net_deleted),'links deleted')
# Out:
# The original network has 2254 links
# There are 14 links added
# There are 5 links deleted

# %% [markdown]
# ## Show the performance on the data

# %%
corr_list = np.zeros((i_test.shape[0], 2))
diet_list = np.zeros((i_test.shape[0], 20))
log_list = np.zeros((i_test.shape[0], 2))
for pa in range(i_test.shape[0]):
    ######## Select an ID of a individual and pull out its experimentally measured metagenome:
    b_real = np.zeros((MAX_ID_microbes,))
    b_real[metagenome_ID] = metagenome.iloc[:, i_test[pa]] / np.sum(metagenome.iloc[:, i_test[pa]])

    ######## Compute matrices involving the metabolite consumption and generation:
    m2b, b2m = Ain_out(b_real, net_new)
    m2b_total, m2m_total, m2m_layer = m2b_multiple_levels(f, m2b, b2m, numLevels_max)

    ######## Assign diet
    x0 = np.ones((len(i_intake),)) / len(i_intake)

    ######## The model is converted into an optimization problem where the nutrient intake is constantly changed to
    # minimize the logarithmic error between experimentally measured metagenome and predicted metagenome computed 
    # from the model for a certain nutrient intake.
    fun = lambda x: pred_error(x, b_real, m2b_total, i_intake)
    bnds = ((0, 100), ) * len(x0)
    res = minimize(fun, x0, method='SLSQP', bounds=bnds, options={'maxiter': 1000}, tol=1e-3)

    ######## As long as the optimized nutrient intake is found by using the above optimization solver, the
    # optimized nutrient intake "res.x" is used to generate the predict metagenome and metabolome. They are
    # visually and statistically compared to the experimentally measured metagenome and metabolome.
    x_full = np.zeros((MAX_ID_metabolites,));
    x_full[i_intake] = res.x;
    ba_pred = np.dot(m2b_total, x_full)

    met_levels, met_leftover_levels = calc_metabolome(res.x, m2m_layer, numLevels_max, i_intake)
    metabolome_measured = np.zeros((MAX_ID_metabolites,))
    metabolome_measured[metabolome_ID] = metabolome.iloc[:, i_test[pa]]
    metabolome_pred = met_levels[:, -1] + met_leftover_levels.sum(1) #np.dot(m2m_total, x_full)
    i_common = np.where(metabolome_measured * metabolome_pred > 1e-5)[0]
    metabolome_pred_common = metabolome_pred[i_common] / np.sum(metabolome_pred[i_common])
    metabolome_measured_common = metabolome_measured[i_common] / np.sum(metabolome_measured[i_common])
    if i_common.shape[0] >= 2:
        corr_list[pa, 0] = pearsonr(ba_pred[b_real>0], b_real[b_real>0])[0]
        corr_list[pa, 1] = pearsonr(np.log10(metabolome_pred_common+1e-5), np.log10(metabolome_measured_common+1e-5))[0]
    else:
        corr_list[pa, 0] = -1
        corr_list[pa, 1] = -1
    diet_list[pa, :] = res.x
    
print('The average Pearson correlation coefficient for the test set:')
print(np.mean(corr_list[:,1]))
print('The average log error for the test set:')
print(np.mean(log_list[:,1]))
# Out:
# The average Pearson correlation coefficient for the test set:
# 0.012132676935017435
# The average log error for the test set:
# 0.0

# %% [markdown]
# ## Construct the added links to a pandas data frame

# %%
NUMADDED = len(net_added)

df_added_metabolites = names.loc[df_metabolites.reset_index().set_index('newID').loc[net_added.iloc[-NUMADDED:,0]].values.flatten()]
df_added_metabolites.reset_index(inplace=True)
df_added_metabolites.columns = ['metabolite ID', 'metabolite names'] 

df_added_microbes = names.loc[df_microbes.reset_index().set_index('newID').loc[net_added.iloc[-NUMADDED:,1]].values.flatten()]
df_added_microbes.reset_index(inplace=True)
df_added_microbes.columns = ['microbes ID', 'microbes names'] 

df_added_edgeTypes = net_added.iloc[-NUMADDED:,2]
df_added_edgeTypes = pd.DataFrame(df_added_edgeTypes)
df_added_edgeTypes.index = range(NUMADDED)

df_added_errorReduced = -np.diff(error_list)[i_added]
df_added_errorReduced = pd.DataFrame(df_added_errorReduced)
df_added_errorReduced.index = range(NUMADDED)
df_added_errorReduced.columns = ['error reduced'] 

df_added_step = np.array(current_step_list)[i_added]
df_added_step = pd.DataFrame(df_added_step)
df_added_step.index = range(NUMADDED)
df_added_step.columns = ['step added'] 

df_added_pos = np.array(pos_x_list)[i_added]
df_added_pos = pd.DataFrame(df_added_pos)
df_added_pos.index = range(NUMADDED)
df_added_pos.columns = ['position in x'] 

df_added_tables = pd.concat([df_added_metabolites, df_added_microbes, df_added_edgeTypes,  df_added_errorReduced, df_added_step, df_added_pos], axis=1, sort=False)
df_added_tables.sort_values(by = 'error reduced', ascending=False)
# Out:
#     metabolite ID                                   metabolite names  \
# 13           2122                Isovalerate (3-Methylbutanoic acid)
# 11           2116                                            Inosine
# 1            2012                                    5-Aminovalerate
# 5            2065                                    D-Galacturonate
# 30           2133  L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...
# 22           2127                              L-Arginine (Arginine)
# 35           2137                                       L-Homoserine
# 17           2049                              Cholic acid (Cholate)
# 4            2068                                D-Glucose (Glucose)
# 58           2133  L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...
# 14           2107                                      H2 (Hydrogen)
# 52           2133  L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...
# 32           2067                        D-Glucosamine (Glucosamine)
# 10           2040                                         Cadaverine
# 23           2105                                            Guanine
# 9            2217                                          Succinate
# 26           2134               L-Glutamine (D-Glutamine, Glutamine)
# 41           2239                                            Uridine
# 16           2009  3-phenylpropionic acid (Phenylpropanoate, 3-ph...
# 60           2125                     L-Alanine (D-Alanine, Alanine)
# 29           2240              Valerate (Pentanoic acid, Pentanoate)
# 44           2053                                            Citrate
# 40           2185                              Orotic acid (Orotate)
# 55           2201                            Propanoate (Propionate)
# 19           2226                     Thiamine (Vitamin B1, Thiamin)
# 7            2203                                         Putrescine
# 34           2049                              Cholic acid (Cholate)
# 12           2193                                           Pentanol
# 49           2201                            Propanoate (Propionate)
# 39           2241                                           Xanthine
# ..            ...                                                ...
# 69           2032                   beta-alanine (3-Aminopropionate)
# 43           2011                             4-Aminobutyrate (GABA)
# 8            2175  N-Acetylneuraminic acid (N-acetylneuraminate, ...
# 51           2185                              Orotic acid (Orotate)
# 15           2122                Isovalerate (3-Methylbutanoic acid)
# 33           2238                                               Urea
# 53           2153                            L-Threonine (Threonine)
# 65           2081                                   Deoxycholic acid
# 0            2229                                            Thymine
# 38           2024    alpha-Tocopherol (Vitamin E, alpha-Tocotrienol)
# 56           2136                            L-Histidine (Histidine)
# 45           2233                                     Trimethylamine
# 50           2155                              L-Tyrosine (Tyrosine)
# 2            2233                                     Trimethylamine
# 27           2060  D-Arabinose (L-Arabinose, Arabinose, L-Arabino...
# 6            2019  Adenosylcobalamin (Vitamin B12, Cobamide coenz...
# 28           2090            Ethanolamine (Phosphatidylethanolamine)
# 66           2116                                            Inosine
# 47           2044  Cellotetraose (Cellohexaose, Cellopentaose, Ce...
# 20           2233                                     Trimethylamine
# 31           2061                              D-Fructose (Fructose)
# 25           2038                                           Butyrate
# 68           2067                        D-Glucosamine (Glucosamine)
# 36           2036                                            Butanol
# 61           2239                                            Uridine
# 42           2037                                         Butylamine
# 62           2122                Isovalerate (3-Methylbutanoic acid)
# 54           2062                                     D-Fructuronate
# 63           2195                                      Phenylacetate
# 67           2207                                          Retinoate
#
#     microbes ID                                     microbes names  edgeType  \
# 13          464                       Faecalibacterium prausnitzii         3
# 11          134                       Bacteroides thetaiotaomicron         3
# 1           329  Collinsella aerofaciens (Eubacterium aerofaciens)         3
# 5           454                                Eubacterium eligens         3
# 30          123                                  Bacteroides dorei         3
# 22          129                                 Bacteroides ovatus         3
# 35          968                                 Ruminococcus obeum         3
# 17          338                                  Coprococcus comes         3
# 4           878                                 Prevotella salivae         2
# 58          457                                Eubacterium rectale         2
# 14          338                                  Coprococcus comes         2
# 52          454                                Eubacterium eligens         3
# 32          157  Bifidobacterium longum (Bifidobacterium infant...         3
# 10         1007                                    Shigella sonnei         3
# 23          968                                 Ruminococcus obeum         3
# 9          1099                          Sutterella wadsworthensis         2
# 26          157  Bifidobacterium longum (Bifidobacterium infant...         2
# 41          964                                Ruminococcus bromii         3
# 16          124                              Bacteroides eggerthii         3
# 60          464                       Faecalibacterium prausnitzii         3
# 29          456                                Eubacterium limosum         3
# 44          137                          Bacteroides xylanisolvens         3
# 40          125      Bacteroides finegoldii (Alistipes finegoldii)         3
# 55          135                              Bacteroides uniformis         2
# 19          137                          Bacteroides xylanisolvens         3
# 7            54                               Alistipes putredinis         2
# 34           54                               Alistipes putredinis         2
# 12          870                                   Prevotella copri         3
# 49          454                                Eubacterium eligens         3
# 39          608                                 Lactococcus lactis         3
# ..          ...                                                ...       ...
# 69          158                  Bifidobacterium pseudocatenulatum         3
# 43         1064                           Streptococcus salivarius         3
# 8           121                              Bacteroides coprocola         3
# 51          137                          Bacteroides xylanisolvens         3
# 15          135                              Bacteroides uniformis         2
# 33           54                               Alistipes putredinis         3
# 53          454                                Eubacterium eligens         3
# 65          952                             Roseburia intestinalis         2
# 0           965                          Ruminococcus flavefaciens         3
# 38          401                                Desulfovibrio piger         3
# 56          309                              Clostridium difficile         3
# 45          329  Collinsella aerofaciens (Eubacterium aerofaciens)         2
# 50          457                                Eubacterium rectale         3
# 2           608                                 Lactococcus lactis         2
# 27          968                                 Ruminococcus obeum         2
# 6           455                                 Eubacterium hallii         3
# 28          968                                 Ruminococcus obeum         3
# 66          968                                 Ruminococcus obeum         2
# 47          952                             Roseburia intestinalis         2
# 20          952                             Roseburia intestinalis         2
# 31          969                               Ruminococcus torques         2
# 25          966                                Ruminococcus gnavus         2
# 68          314                                 Clostridium leptum         3
# 36           55                                   Alistipes shahii         3
# 61          964                                Ruminococcus bromii         2
# 42          260                          Catenibacterium mitsuokai         3
# 62          260                          Catenibacterium mitsuokai         3
# 54          123                                  Bacteroides dorei         2
# 63           46                            Akkermansia muciniphila         3
# 67          460                                Eubacterium siraeum         2
#
#     error reduced  step added  position in x
# 13   1.844743e-02         325          23660
# 11   1.332175e-02         271          23200
# 1    1.320793e-02          30          16736
# 5    1.196131e-02         113          19982
# 30   1.128696e-02         996          24345
# 22   9.566429e-03         558          23917
# 35   8.807495e-03        1146          24688
# 17   7.812703e-03         379          19041
# 4    7.025520e-03          78           4304
# 58   6.083423e-03        2209           8465
# 14   5.915619e-03         334           6873
# 52   5.881095e-03        1866          24374
# 32   5.329910e-03        1039          20111
# 10   5.329638e-03         240          18570
# 23   5.252280e-03         598          22672
# 9    5.223751e-03         222          14111
# 26   4.961538e-03         707           8519
# 41   4.586705e-03        1341          31525
# 16   4.146937e-03         368          16498
# 60   3.942222e-03        2428          23804
# 29   3.358106e-03         970          31576
# 44   2.997298e-03        1373          19242
# 40   2.743548e-03        1247          27875
# 55   2.401912e-03        2045          12977
# 19   2.389538e-03         408          30618
# 7    2.235055e-03         189          13106
# 34   2.117413e-03        1133           3098
# 12   1.897985e-03         318          28423
# 49   1.593203e-03        1754          28910
# 39   1.451015e-03        1209          31657
# ..            ...         ...            ...
# 69   5.594825e-04        2678          18024
# 43   4.415987e-04        1354          16701
# 8    4.179560e-04         204          27223
# 51   4.090147e-04        1843          27882
# 15   2.675129e-04         361           7721
# 33   2.313251e-04        1092          31394
# 53   2.172182e-04        1874          25814
# 65   2.166116e-04        2531           5243
# 0    1.830720e-04          15          30878
# 38   9.154606e-05        1205          17531
# 56   4.180515e-05        2054          24580
# 45   1.594808e-05        1413          15152
# 50   6.671989e-06        1802          25961
# 2    7.552419e-07          42          15169
# 27  -4.737172e-05         856           3736
# 6   -7.774698e-05         118          17247
# 28  -8.808849e-05         961          21736
# 66  -8.995019e-05        2577           7336
# 47  -1.575806e-04        1494           2939
# 20  -1.592162e-04         470          15179
# 31  -2.764878e-04        1029           3809
# 25  -2.960926e-04         645           2583
# 68  -4.485705e-04        2669          20117
# 36  -6.393945e-04        1171          18291
# 61  -7.083394e-04        2470          15613
# 42  -7.774267e-04        1345          18387
# 62  -9.306140e-04        2502          23643
# 54  -1.000000e-03        2011           3825
# 63  -1.000000e-03        2510          28513
# 67  -1.000000e-03        2606          13434
#
# [70 rows x 8 columns]

# %% [markdown]
# ## Construct the added links to a pandas data frame

# %%
NUMdeleted = len(net_deleted)

df_deleted_metabolites = names.loc[df_metabolites.reset_index().set_index('newID').loc[net_deleted.iloc[-NUMdeleted:,0]].values.flatten()]
df_deleted_metabolites.reset_index(inplace=True)
df_deleted_metabolites.columns = ['metabolite ID', 'metabolite names'] 

df_deleted_microbes = names.loc[df_microbes.reset_index().set_index('newID').loc[net_deleted.iloc[-NUMdeleted:,1]].values.flatten()]
df_deleted_microbes.reset_index(inplace=True)
df_deleted_microbes.columns = ['microbes ID', 'microbes names'] 

df_deleted_edgeTypes = net_deleted.iloc[-NUMdeleted:,2]
df_deleted_edgeTypes = pd.DataFrame(df_deleted_edgeTypes)
df_deleted_edgeTypes.index = range(NUMdeleted)

df_deleted_errorReduced = -np.diff(error_list)[i_deleted]
df_deleted_errorReduced = pd.DataFrame(df_deleted_errorReduced)
df_deleted_errorReduced.index = range(NUMdeleted)
df_deleted_errorReduced.columns = ['error reduced'] 

df_deleted_step = np.array(current_step_list)[i_deleted]
df_deleted_step = pd.DataFrame(df_deleted_step)
df_deleted_step.index = range(NUMdeleted)
df_deleted_step.columns = ['step deleted'] 

df_deleted_pos = np.array(pos_x_list)[i_deleted]
df_deleted_pos = pd.DataFrame(df_deleted_pos)
df_deleted_pos.index = range(NUMdeleted)
df_deleted_pos.columns = ['position in x'] 

df_deleted_tables = pd.concat([df_deleted_metabolites, df_deleted_microbes, df_deleted_edgeTypes,  df_deleted_errorReduced, df_deleted_step, df_deleted_pos], axis=1, sort=False)
df_deleted_tables.sort_values(by = 'error reduced', ascending=False)
# Out:
#     metabolite ID                                   metabolite names  \
# 5            2122                Isovalerate (3-Methylbutanoic acid)
# 4            2107                                      H2 (Hydrogen)
# 13           2055                                                CO2
# 17           2055                                                CO2
# 26           2238                                               Urea
# 0            2098                                           Glycerol
# 14           2204  Pyridoxal (Vitamin B6, Pyridoxine, Pyridoxamin...
# 11           2163                           Menaquinone (Vitamin K2)
# 46           2133  L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...
# 21           2072                                D-Mannose (Mannose)
# 12           2019  Adenosylcobalamin (Vitamin B12, Cobamide coenz...
# 2            2065                                    D-Galacturonate
# 56           2203                                         Putrescine
# 36           2108                                               H2O2
# 15           2002  1,2-diacylglycerol (1-acylglycerol, Monoacylgl...
# 22           2109                                          H2S (HS-)
# 49           2028  Ascorbic acid (Vitamin C, L-Ascorbate, Ascorbate)
# 53           2099                             Glycochenodeoxycholate
# 60           2060  D-Arabinose (L-Arabinose, Arabinose, L-Arabino...
# 27           2055                                                CO2
# 9            2122                Isovalerate (3-Methylbutanoic acid)
# 43           2098                                           Glycerol
# 28           2157                                            Lactose
# 31           2061                              D-Fructose (Fructose)
# 23           2203                                         Putrescine
# 57           2178                      NH3 (Ammonia, NH4+, Ammonium)
# 16           2178                      NH3 (Ammonia, NH4+, Ammonium)
# 3            2236                                           Tyramine
# 51           2238                                               Urea
# 44           2099                             Glycochenodeoxycholate
# ..            ...                                                ...
# 10           2109                                          H2S (HS-)
# 59           2141  L-Lactate ([S]-Lactate, Lactate, D-Lactate, [R...
# 45           2122                Isovalerate (3-Methylbutanoic acid)
# 20           2196                                   Phenylethylamine
# 54           2238                                               Urea
# 18           2196                                   Phenylethylamine
# 19           2133  L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...
# 8            2082  Dextrin (Maltotriose, Maltodextrin, Maltohexao...
# 29           2204  Pyridoxal (Vitamin B6, Pyridoxine, Pyridoxamin...
# 40           2122                Isovalerate (3-Methylbutanoic acid)
# 30           2049                              Cholic acid (Cholate)
# 47           2238                                               Urea
# 24           2055                                                CO2
# 25           2061                              D-Fructose (Fructose)
# 1            2236                                           Tyramine
# 42           2161                                            Maltose
# 34           2068                                D-Glucose (Glucose)
# 37           2028  Ascorbic acid (Vitamin C, L-Ascorbate, Ascorbate)
# 55           2178                      NH3 (Ammonia, NH4+, Ammonium)
# 35           2157                                            Lactose
# 50           2014                                            Acetate
# 52           2082  Dextrin (Maltotriose, Maltodextrin, Maltohexao...
# 41           2038                                           Butyrate
# 39           2240              Valerate (Pentanoic acid, Pentanoate)
# 32           2073                                          D-Psicose
# 7            2002  1,2-diacylglycerol (1-acylglycerol, Monoacylgl...
# 48           2014                                            Acetate
# 58           2034  Bicarbonate (HCO3-, H2CO3, Carbonic acid, Carb...
# 6            2060  D-Arabinose (L-Arabinose, Arabinose, L-Arabino...
# 33           2108                                               H2O2
#
#     microbes ID                                     microbes names  edgeType  \
# 5           952                             Roseburia intestinalis         3
# 4           161           Blautia hansenii (Ruminococcus hansenii)         2
# 13          123                                  Bacteroides dorei         2
# 17          137                          Bacteroides xylanisolvens         2
# 26         1064                           Streptococcus salivarius         3
# 0           966                                Ruminococcus gnavus         2
# 14          964                                Ruminococcus bromii         2
# 11          513                         Haemophilus parainfluenzae         2
# 46          131                               Bacteroides plebeius         2
# 21          968                                 Ruminococcus obeum         2
# 12          964                                Ruminococcus bromii         2
# 2           126                               Bacteroides fragilis         2
# 56           55                                   Alistipes shahii         3
# 36          895                    Pseudoflavonifractor capillosus         2
# 15          161           Blautia hansenii (Ruminococcus hansenii)         2
# 22          460                                Eubacterium siraeum         3
# 49          152                            Bifidobacterium bifidum         3
# 53           54                               Alistipes putredinis         3
# 60          461                             Eubacterium ventriosum         3
# 27          119                                 Bacteroides caccae         2
# 9           952                             Roseburia intestinalis         3
# 43          966                                Ruminococcus gnavus         2
# 28          812                         Parabacteroides distasonis         2
# 31          134                       Bacteroides thetaiotaomicron         2
# 23           55                                   Alistipes shahii         3
# 57          425                                  Eggerthella lenta         2
# 16          965                          Ruminococcus flavefaciens         2
# 3           126                               Bacteroides fragilis         2
# 51         1064                           Streptococcus salivarius         3
# 44           54                               Alistipes putredinis         3
# ..          ...                                                ...       ...
# 10          460                                Eubacterium siraeum         3
# 59          401                                Desulfovibrio piger         2
# 45          457                                Eubacterium rectale         2
# 20          119                                 Bacteroides caccae         2
# 54          158                  Bifidobacterium pseudocatenulatum         2
# 18          119                                 Bacteroides caccae         2
# 19          131                               Bacteroides plebeius         2
# 8           134                       Bacteroides thetaiotaomicron         2
# 29          608                                 Lactococcus lactis         2
# 40          457                                Eubacterium rectale         2
# 30          314                                 Clostridium leptum         2
# 47          323                               Clostridium scindens         2
# 24          124                              Bacteroides eggerthii         2
# 25          129                                 Bacteroides ovatus         2
# 1           126                               Bacteroides fragilis         2
# 42          329  Collinsella aerofaciens (Eubacterium aerofaciens)         2
# 34          814                             Parabacteroides merdae         2
# 37          152                            Bifidobacterium bifidum         3
# 55          425                                  Eggerthella lenta         2
# 35          796                           Odoribacter splanchnicus         2
# 50          952                             Roseburia intestinalis         2
# 52          964                                Ruminococcus bromii         2
# 41          314                                 Clostridium leptum         3
# 39           75                                Anaerostipes caccae         3
# 32          129                                 Bacteroides ovatus         2
# 7           161           Blautia hansenii (Ruminococcus hansenii)         2
# 48          880                              Prevotella timonensis         3
# 58          964                                Ruminococcus bromii         2
# 6           461                             Eubacterium ventriosum         3
# 33          895                    Pseudoflavonifractor capillosus         2
#
#     error reduced  step deleted  position in x
# 5        0.019988           286          23675
# 4        0.011876           275           6866
# 13       0.005725           479           3393
# 17       0.004862           572           3402
# 26       0.003845           819          31461
# 0        0.003131            28           6255
# 14       0.002847           488          13237
# 11       0.002550           421          10631
# 46       0.002350          1588           8438
# 21       0.002256           671           4600
# 12       0.001469           461           1357
# 2        0.001191           220           4044
# 56       0.001175          2344          29019
# 36       0.001126          1062           6970
# 15       0.001000           528             98
# 22       0.000988           732          22938
# 49       0.000973          1727          17733
# 53       0.000964          1906          22178
# 60       0.000903          2638          19627
# 27       0.000876           821           3390
# 9        0.000798           390          23675
# 43       0.000777          1525           6255
# 28       0.000717           892          10204
# 31       0.000669           974           3760
# 23       0.000664           748          29019
# 57       0.000633          2360          11485
# 16       0.000497           560          11510
# 3        0.000487           247          15348
# 51       0.000413          1890          31461
# 44       0.000402          1554          22178
# ..            ...           ...            ...
# 10       0.000293           401          22938
# 59       0.000237          2623           9035
# 45       0.000221          1563           7745
# 20       0.000004           655          12678
# 54      -0.000016          2032          15504
# 18      -0.000068           615          12678
# 19      -0.000116           637           8438
# 8       -0.000116           373           5272
# 29      -0.000131           925          13225
# 40      -0.000141          1384           7745
# 30      -0.000148           936           3125
# 47      -0.000151          1589          15510
# 24      -0.000363           754           3394
# 25      -0.000363           805           3757
# 1       -0.000500           122          15348
# 42      -0.000518          1463          10472
# 34      -0.000551          1038           4302
# 37      -0.000591          1066          17733
# 55      -0.000619          2243          11485
# 35      -0.000699          1046          10202
# 50      -0.000707          1759            995
# 52      -0.000864          1891           5317
# 41      -0.001000          1405          18461
# 39      -0.001000          1367          31540
# 32      -0.001000           977           4621
# 7       -0.001000           372             98
# 48      -0.001000          1655          16905
# 58      -0.001000          2426           2293
# 6       -0.001022           333          19627
# 33      -0.001144          1013           6970
#
# [61 rows x 8 columns]

# %% [markdown]
# ## Visualize error reduction over time and rank plot of error reduction

# %%
plt.figure()
plt.plot(np.cumsum(np.sort(df_added_tables['error reduced'].values))[::-1])
plt.yscale('log')
plt.ylabel('per link error reduction')
plt.xlabel('rank of links')

plt.figure()
plt.plot(error_list)
plt.ylabel('error')
plt.xlabel('number of links added')
# Out:
# Text(0.5, 0, 'number of links added')

# %% [markdown]
# ## Generate p-value by comparing the added links to links in the MAMBO

# %%
chia_microbes_in_Thai = df_microbes.reset_index().set_index('newID').loc[metagenome_ID].values.flatten()
chia_metabolites_in_Thai = df_metabolites.reset_index().set_index('newID').loc[df_metabolites['newID']].values.flatten()

df_MAMBO = pd.read_csv("mambo_curated.txt", sep = '\t')
df_MAMBO_filtered = df_MAMBO[df_MAMBO['microbe_ID'].apply(lambda x: x in chia_microbes_in_Thai)]
df_MAMBO_filtered = df_MAMBO_filtered[df_MAMBO_filtered['metabolite_ID'].apply(lambda x: x in chia_metabolites_in_Thai)]

df_MAMBO_filtered_newID = df_MAMBO_filtered[['microbe_ID', 'metabolite_ID']].copy()
df_MAMBO_filtered_newID.columns = ['microbes', 'metabolites']
df_MAMBO_filtered_newID['microbes'] = df_microbes.loc[df_MAMBO_filtered_newID['microbes']].values
df_MAMBO_filtered_newID['metabolites'] = df_metabolites.loc[df_MAMBO_filtered_newID['metabolites']].values
s1 = df_MAMBO_filtered_newID
s2 = net[['metabolites', 'microbes']]
numOverlap = len(pd.merge(s1, s2, how='inner'))

print((len(df_MAMBO_filtered)-numOverlap), (x.shape[0] - len(net_ori)))
print((len(df_MAMBO_filtered)-numOverlap) / (x.shape[0] - len(net_ori)) )

k = 0
l = 0
ifIncluded = np.zeros((NUMADDED))
ifCovered = np.zeros((NUMADDED))
for i in range(NUMADDED):
    if (np.sum((df_MAMBO['microbe_ID'] == df_added_tables['microbes ID'].iloc[i])) >=1 and 
       np.sum((df_MAMBO['metabolite_ID'] == df_added_tables['metabolite ID'].iloc[i]))>=1):
        ifCovered[i] = 1
        l += 1
    if np.sum((df_MAMBO['microbe_ID'] == df_added_tables['microbes ID'].iloc[i]) & 
       (df_MAMBO['metabolite_ID'] == df_added_tables['metabolite ID'].iloc[i]))>=1:
        ifIncluded[i] = 1
        k += 1
print('Of '+str(l)+' valid links existing in MAMBO, there are '+str(k)+' found by the GutCP.')

from scipy.stats import bernoulli, binom
xx = range(NUMADDED)
p = len(df_MAMBO_filtered) / x.shape[0]
#prob = bernoulli.cdf(xx, p)
probCum = binom.cdf(xx, NUMADDED, p)
prob = binom.pmf(xx, NUMADDED, p)
plt.plot(xx, prob, 'o')
plt.plot([k, k], [0, np.max(prob)], '-.')
plt.xlabel('Number of predicted links in MAMBO')
plt.ylabel('Probability')
p_value = 1 - probCum[k]
print('The p-value of this is',str(p_value))
# Out:
# 3217 30749
# 0.1046212884971869
# Of 48 valid links existing in MAMBO, there are 25 found by the GutCP.
# The p-value of this is 5.116521195613899e-08
